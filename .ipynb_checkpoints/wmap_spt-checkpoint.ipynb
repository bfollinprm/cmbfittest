# %%
import cmbfittest as fit

# %%
from scipy.ndimage.filters import gaussian_filter1d as gaussian_filter
from numpy.random import multivariate_normal as normal
from numpy.random import normal as N
from numpy import dot, sqrt, zeros, array, arange, save, mean, std
from numpy.linalg import inv, eigh
from scipy.linalg import sqrtm
from matplotlib.colors import LogNorm

# %%
### Instancing models
primordial = fit.model.model('primordial', ellmax = 2500, force_calculation = False)
lcdm = fit.model.model('lcdm', ellmax = 2500, force_calculation = False)
primordial.get_dcldphi()
lcdm.get_dcldphi()
primordial.get_covariance()
lcdm.get_covariance()
primordial.save_dcldphi()
lcdm.save_dcldphi()

# %%
lcdm.dcldphi = gaussian_filter(lcdm.dcldphi, sigma = 20, axis = 0)
primordial.dcldphi= gaussian_filter(primordial.dcldphi, sigma = 20, axis = 0)

# %%
#plot(primordial.dcldphi);
#xlabel('multipole $l$', fontsize = 20)
#ylabel(r'$\delta C_l \left[\mu {\rm k}^2\right]$', fontsize = 20)
#savefig('responses.png')

# %%
### SPT
spt = fit.data.data('spt', ellmax = 2500)
spt.get_covariance()
spt.get_bandpowers()
spt.get_window_functions()

# %%
### WMAP
wmap = fit.data.data('wmap', ellmax = 2500)
wmap.get_covariance()
wmap.get_bandpowers()
wmap.get_window_functions()
# Out:
# src/data.py:118: RuntimeWarning: divide by zero encountered in divide
#   inv_covariance = np.diag(1.0/np.diag(tttt)) - R_eff/(tttt) + Epsilon/tttt**2
# src/data.py:118: RuntimeWarning: invalid value encountered in divide
#   inv_covariance = np.diag(1.0/np.diag(tttt)) - R_eff/(tttt) + Epsilon/tttt**2

# %%
print wmap.windows.shape
print wmap.observation.shape
print wmap.covariance.shape
print lcdm.dcldphi.shape
# Out:
# (1199, 2501)
# (1199,)
# (1199, 1199)
# (2501, 6)

# %%
fisher_lcdm = fit.model.model('lcdm', ellmax = 2500)
parameter_prior_cov = inv(
                          dot(
                              dot(lcdm.dcldphi.T, wmap.windows.T[:2501,:]),
                              dot(
                                  inv(wmap.covariance),
                                  dot(wmap.windows[:,:2501],lcdm.dcldphi)
                                  )
                              )
                        + dot(
                              dot(lcdm.dcldphi.T, spt.windows.T[:2501,:]),
                              dot(
                                  inv(spt.covariance),
                                  dot(spt.windows[:,:2501],lcdm.dcldphi)
                                  )
                              )
                          )
fisher_lcdm.dcldphi = dot(lcdm.dcldphi, parameter_prior_cov)
fisher_lcdm.get_covariance()
imshow(fisher_lcdm.covariance)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x114213dd0>

# %%
#imshow(
#       abs(wmap.covariance),
#       norm = LogNorm(vmin = 10, vmax = 1e4)
#        )
#colorbar()
#figure()
#imshow(abs((spt.covariance)), 
#       norm = LogNorm(vmin = 10, vmax=1e4)
#       )
#colorbar()
#figure()
#plot(sqrt(diag(wmap.covariance)))
#figure()
#plot(sqrt(diag(spt.covariance)))

# %%
lda=fit.scheme.compression_scheme(
                                    'LDA',
                                    dcldphi = primordial.dcldphi,
                                    noise_cov = [spt.covariance,wmap.covariance],
                                    windows = [spt.windows, wmap.windows],
                                    supermodel_cov = primordial.covariance,
                                    kappa = 1000, 
                                    SM_cov = fisher_lcdm.covariance,
                                    nummodes = 20,
                                    ellmax = 3000
                                    )

# %%
lda.get_compression_modes()
# Out:
# /Users/follin/projects/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:460: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
semilogx(lda.modes[:-1,0:20]);

# %%
n = 1
chisqlist = zeros(n)
maxchisqlist = zeros(n)
globalz = zeros(n)
from numpy.random import normal as N
def randN(scale = 0):
    if scale ==0:
        return 0
    else:
        return N(scale = scale)
def add_noise(spectrum, sigma, orthogonal_modes):
    return spectrum + dot(
                          orthogonal_modes, 
                          array([randN(scale = sigma[j]) for j in arange(spectrum.size)])
                          )
for ii in arange(n):
    cloud = fit.sim.gauss_approx(
                                 observation = [spt.observation, wmap.observation[2:800]],
                                 covariance = [spt.covariance, wmap.covariance[2:800,2:800]],
                                 windows = [spt.windows, wmap.windows[:798,:798]],
                                 deltaCl = lcdm.dcldphi,
                                 ellmax = 2500
                                 )
    cloud.get_bestfit()
    print cloud.best_fit.shape
    plot(cloud.best_fit)
    #variance, ortho_modes = eigh(spt.covariance[:3000, :3000])
    #sigma = sqrt(variance)
    #noisydraws = array(map(lambda x:add_noise(x, sigma, orthogonal_modes), draws.tolist()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-86eeaaa08b08> in <module>()
#      21                                  deltaCl = lcdm.dcldphi
#      22                                  )
# ---> 23     cloud.get_bestfit()
#      24     print cloud.best_fit.shape
#      25     plot(cloud.best_fit)
#
# /Users/follin/projects/gitrepos/cmbfittest/src/simulate.pyc in get_bestfit(self)
#     179     def get_bestfit(self):
#     180         x0 = self.cosmo_to_x()
# --> 181         minresult = minimize(self.lnl, x0, method = 'Nelder-Mead')
#     182         self.best_fit = self.get_cmb(outputs=['cl_TT'], force = True, **self.cosmo)['cl_TT'][:self.ellmax + 1]
#     183         #self.best_fit = np.array([self.best_fit for i in np.arange(self.numexperiments)]).flatten()
#
# /Users/follin/projects/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     411                       callback=callback, **options)
#     412     elif meth == 'nelder-mead':
# --> 413         return _minimize_neldermead(fun, x0, args, callback, **options)
#     414     elif meth == 'powell':
#     415         return _minimize_powell(fun, x0, args, callback, **options)
#
# /Users/follin/projects/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in _minimize_neldermead(func, x0, args, callback, xtol, ftol, maxiter, maxfev, disp, return_all, **unknown_options)
#     436     if retall:
#     437         allvecs = [sim[0]]
# --> 438     fsim[0] = func(x0)
#     439     nonzdelt = 0.05
#     440     zdelt = 0.00025
#
# /Users/follin/projects/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# /Users/follin/projects/gitrepos/cmbfittest/src/simulate.pyc in lnl(self, x)
#     146             inv_cov = self.inv_cov[i]
#     147             print self.windows[i].shape, cl_TT[2:self.windows[i].shape[1]+2].shape
# --> 148             dx = np.dot(self.windows[i], cl_TT[2:self.windows[i].shape[1]+2]) - self.observation[i]
#     149             lnl += np.dot(dx, np.dot(self.inv_cov[i], dx))
#     150         print lnl
#
# ValueError: matrices are not aligned
# (47, 2501) (2500,)

# %%
draws = array([cloud.sample() for i in arange(10000)])

# %%
matshow(log(abs(inv(wmap.covariance[2:1202,2:1202]))))

# %%
print wmap.covariance.shape, wmap.observation.shape, wmap.windows.shape
