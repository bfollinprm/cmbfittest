# %%
import model

# %%
primordial = model.model('primordial')

# %%
primordial.get_dcldphi()

# %%
plot(primordial.dcldphi);

# %%
from scipy.ndimage.filters import gaussian_filter

# %%
primordial.dcldphi_smooth = gaussian_filter(primordial.dcldphi, sigma = 2)

# %%
plot(primordial.dcldphi_smooth);
primordial.save_dcldphi()

# %%
primordial.get_covariance()
plot(primordial.covariance[:,1200])

# %%
import data

# %%
experiment = data.data('planck_like')

# %%
experiment.get_covariance()

# %%
#experiment.get_bandpowers()

# %%
primordial.dcldphi_smooth.shape
# Out:
# (5001, 200)

# %%
#plot(experiment.observation[:2500])

# %%
import compression_scheme

# %%
lda = compression_scheme.compression_scheme('max_cov', dcldphi = primordial.dcldphi_smooth, noise_cov = experiment.covariance, supermodel_cov = primordial.covariance, kappa = 0)

# %%
lda.get_compression_modes()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-c71ca05204b0> in <module>()
# ----> 1 lda.get_compression_modes()
#
# /Users/follin/projects/goodness_of_fit/trunk/CMBFitTest/src/compression_scheme.py in get_compression_modes(self)
#      43
#      44         def get_compression_modes(self):
# ---> 45                 self.eigspectrum, self.modes = compute.get_modes(self)
#      46
#      47                 self.modes = self.modes[:nummodes]
#
# /Users/follin/projects/goodness_of_fit/trunk/CMBFitTest/src/compute.py in get_modes(test)
#     212
#     213         if test.type == 'max_cov':
# --> 214                 w, modes = eig(np.dot(inv(test.noise_cov[2:,2:]) + test.kappa * test.SM_cov[2:,2:], test.supermodel_cov[2:,2:]))
#     215
#     216         if test.type == 'fisher':
#
# ...
