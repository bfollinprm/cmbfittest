# %%
import model

# %%
primordial = model.model('primordial')
lcdm = model.model('lcdm')

# %%
primordial.get_dcldphi()
lcdm.get_dcldphi()

# %%
primordial.dcldphi = primordial.dcldphi[:2501,:]
lcdm.dcldphi = lcdm.dcldphi[:2501,:]

# %%
from scipy.ndimage.filters import gaussian_filter1d as gaussian_filter

# %%
lcdm.dcldphi_smooth = gaussian_filter(lcdm.dcldphi, sigma = 20, axis = 0)
primordial.dcldphi_smooth = gaussian_filter(primordial.dcldphi, sigma = 20, axis = 0)

# %%
plot(primordial.dcldphi_smooth);
primordial.save_dcldphi()
lcdm.save_dcldphi() 
#.dcldphi / dot(lcdm.dcldphi, lcdm.dcldphi).reshape(-1,1)

# %%
row_sums = sqrt((lcdm.dcldphi**2).sum(axis = 0))
lcdm.dcldphi = lcdm.dcldphi /row_sums
plot(lcdm.dcldphi);

# %%
primordial.get_covariance()
lcdm.get_covariance()

# %%
imshow(lcdm.covariance)
colorbar()
import data

# %%
experiment = data.data('planck_like')

# %%
experiment.get_covariance()

# %%
#experiment.get_bandpowers()

# %%
primordial.dcldphi_smooth.shape
# Out:
# (2501, 200)

# %%
#plot(experiment.observation[:2500])

# %%
import compression_scheme

# %%
lda = compression_scheme.compression_scheme('max_cov', dcldphi = primordial.dcldphi_smooth, noise_cov = experiment.covariance, supermodel_cov = primordial.covariance, kappa = 1.0e10, SM_cov = lcdm.covariance)

# %%
lda.get_compression_modes()

# %%
plot(lda.modes[:,:5]);

# %%
import simulate
from numpy.random import multivariate_normal as normal
observation = experiment.fiducial_cl[:2501] + normal(np.zeros(2501), experiment.covariance[:2501,:2501])

# %%
cloud = simulate.gauss_approx(observation = observation, covariance = experiment.covariance)

# %%
cloud.get_bestfit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-f67829efcd02> in <module>()
# ----> 1 cloud.get_bestfit()
#
# /Users/follin/projects/gitrepos/cmbfittest/src/simulate.py in get_bestfit(self)
#     162     def get_bestfit(self):
#     163         x0 = self.cosmo_to_x()
# --> 164         minresult = minimize(self.lnl, x0, method = 'BFGS')
#     165         x_bestfit = minresult.x
#     166         self.best_fit = self.get_cmb(outputs=['cl_TT'], force = True, **self.x_to_cosmo(x_bestfit))['cl_TT'][:2501]
#
# /Users/follin/projects/anaconda/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     417         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     418     elif meth == 'bfgs':
# --> 419         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     420     elif meth == 'newton-cg':
#     421         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# /Users/follin/projects/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#     830     else:
#     831         grad_calls, myfprime = wrap_function(fprime, args)
# --> 832     gfk = myfprime(x0)
#     833     k = 0
#     834     N = len(x0)
#
# /Users/follin/projects/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# /Users/follin/projects/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in approx_fprime(xk, f, epsilon, *args)
#     602
#     603     """
# --> 604     f0 = f(*((xk,) + args))
#     605     grad = numpy.zeros((len(xk),), float)
#     606     ei = numpy.zeros((len(xk),), float)
#
# /Users/follin/projects/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     279     def function_wrapper(*wrapper_args):
#     280         ncalls[0] += 1
# --> 281         return function(*(wrapper_args + args))
#     282
#     283     return ncalls, function_wrapper
#
# /Users/follin/projects/gitrepos/cmbfittest/src/simulate.py in lnl(self, x)
#     128         #cosmo['H0'] = 70#self.hubble_theta.theta_to_hubble(**cosmo)
#     129
# --> 130         cl_TT = self.get_cmb(outputs=['cl_TT'],force=True,**cosmo)['cl_TT'][:2501]
#     131         lnl = self.tau_prior()
#     132         dx = np.dot(self.windows, cl_TT) - self.observation
#
# /Users/follin/projects/anaconda/lib/python2.7/site-packages/cosmoslik_plugins/models/pico.pyc in __call__(self, outputs, force, onfail, **kwargs)
#      24
#      25         try:
# ---> 26             return self.pico.get(outputs=outputs,force=force,**kwargs)
#      27         except pypico.CantUsePICO:
#      28             if onfail is None: raise
#
# <string> in get(self, outputs, force, **inputs)
#
# <string> in get_result(self, inputs, derive, force)
#
# <string> in inputs_to_xinputs(self, **inputs)
#
# KeyError: 'massive_neutrinos'
